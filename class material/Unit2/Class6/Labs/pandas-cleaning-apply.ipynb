# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Lab: Cleaning Rock Song Data
#
# _Authors: Dave Yerrington (SF)_
#
# ---

# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### 1. Load `rock.csv` and do an initial examination of its data columns.

# %%
rockfile = ("/Users/swllms/DAT-10-14/class material/Unit2/data/rock.csv")

# %%
# Load the data.
rf = pd.read_csv(rockfile)
rf.head()
# Out:
#                Song Clean ARTIST CLEAN Release Year  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special          NaN
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                 COMBINED  First?  Year?  PlayCount  F*G
# 0        Caught Up in You by .38 Special       1      1         82   82
# 1            Fantasy Girl by .38 Special       1      0          3    0
# 2         Hold On Loosely by .38 Special       1      1         85   85
# 3  Rockin' Into the Night by .38 Special       1      1         18   18
# 4              Art For Arts Sake by 10cc       1      1          1    1

# %%
# Look at the information regarding its columns.
rf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 8 columns):
# Song Clean      2230 non-null object
# ARTIST CLEAN    2230 non-null object
# Release Year    1653 non-null object
# COMBINED        2230 non-null object
# First?          2230 non-null int64
# Year?           2230 non-null int64
# PlayCount       2230 non-null int64
# F*G             2230 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 139.5+ KB

# %% [markdown]
# ### 2.  Clean up the column names.
#
# Let's clean up the column names. There are two ways we can accomplish this:
#
# #### 2.A Change the column names when you import the data using `pd.read_csv()`.
#
# Notice that, when passing `names=[..A LIST OF STRING..]` with a number of columns that matches the number of strings in the passed list, you replace the column names.
#
# NOTE: When you create custom column names, the first row of the `.csv` already represents a header. It is important to tell `pandas` to skip that row. The `skiprows=1` keyword argument to `read_csv()` will tell `pandas` to skip the first row.

# %%
# Change the column names when loading the '.csv':
column_names = ['Song', 'Artist', 'RYR', 'Song_Artist', 'First', 'Year', 'CountPlay', 'FG']
rf = pd.read_csv(rockfile, names=column_names, skiprows =1)

# %%
rf.head()
# Out:
#                      Song       Artist   RYR  \
# 0        Caught Up in You  .38 Special  1982
# 1            Fantasy Girl  .38 Special   NaN
# 2         Hold On Loosely  .38 Special  1981
# 3  Rockin' Into the Night  .38 Special  1980
# 4       Art For Arts Sake         10cc  1975
#
#                              Song_Artist  First  Year  CountPlay  FG
# 0        Caught Up in You by .38 Special      1     1         82  82
# 1            Fantasy Girl by .38 Special      1     0          3   0
# 2         Hold On Loosely by .38 Special      1     1         85  85
# 3  Rockin' Into the Night by .38 Special      1     1         18  18
# 4              Art For Arts Sake by 10cc      1     1          1   1

# %% [markdown]
# #### 2.B Change column names using the `.rename()` function.
#
# The `.rename()` function takes an argument, `columns=name_dict`, in which `name_dict` is a dictionary containing the original column names as keys and the new column names as values.

# %%
# Change the column names using the `.rename()` function.
name_dict = {'Song': 'Songs','Artist': 'ArtistC','RYR': 'Rel_Yr','Song_Artist': 'Song_Art','First': '1st','Year': 'YR', 'PlayCount': 'PlayC', 
'FG': 'F*G'}
rf.rename(columns=name_dict) 

### can also use rf = rf.rename({}) axis=1, inplace=True) 
### new cols = [col.lower() for col in rf.colums.tolist]
# Out:
#                                             Songs        ArtistC Rel_Yr  \
# 0                                Caught Up in You    .38 Special   1982
# 1                                    Fantasy Girl    .38 Special    NaN
# 2                                 Hold On Loosely    .38 Special   1981
# 3                          Rockin' Into the Night    .38 Special   1980
# 4                               Art For Arts Sake           10cc   1975
# 5                                      Kryptonite   3 Doors Down   2000
# 6                                           Loser   3 Doors Down   2000
# 7                                   When I'm Gone   3 Doors Down   2002
# 8                                      What's Up?  4 Non Blondes   1992
# 9                                      Take On Me           a-ha   1985
# 10                          Baby, Please Don't Go          AC/DC    NaN
# 11                                  Back In Black          AC/DC   1980
# 12                                        Big Gun          AC/DC   1993
# 13                         CAN'T STOP ROCK'N'ROLL          AC/DC    NaN
# 14                    Dirty Deeds Done Dirt Cheap          AC/DC   1976
# 15                        For Those About To Rock          AC/DC   1981
# 16                               Girls Got Rhythm          AC/DC    NaN
# 17                                 Hard As A Rock          AC/DC   1995
# 18                             Have a Drink On Me          AC/DC   1980
# 19                                    Hells Bells          AC/DC   1980
# 20                                Highway To Hell          AC/DC   1979
# 21                     It's A Long Way To The Top          AC/DC   1975
# 22                                      Jailbreak          AC/DC   1984
# 23                              Let There Be Rock          AC/DC   1977
# 24                                Let's Get It Up          AC/DC    NaN
# 25                                      Live Wire          AC/DC    NaN
# 26                                     Moneytalks          AC/DC    NaN
# 27                                  Night Prowler          AC/DC   1979
# 28            Rock and Roll Ain't Noise Pollution          AC/DC   1980
# 29                                Shoot To Thrill          AC/DC    NaN
# ...                                           ...            ...    ...
# 2200                      Owner of a Lonely Heart            Yes   1983
# 2201                                   Roundabout            Yes   1971
# 2202                             Starship Trooper            Yes   1971
# 2203                            Wonderous Stories            Yes    NaN
# 2204                         Yours Is No Disgrace            Yes   1971
# 2205                        Tell Me What You Want          Zebra    NaN
# 2206                        Who's Behind The Door          Zebra    NaN
# 2207                           Time of the Season        Zombies   1968
# 2208                    A Fool for Your Stockings         ZZ Top    NaN
# 2209             Arrested For Driving While Blind         ZZ Top   1976
# 2210                 Beer Drinkers & Hell Raisers         ZZ Top   1973
# 2211                             Cheap Sunglasses         ZZ Top   1980
# 2212                         Gimme All Your Lovin         ZZ Top   1983
# 2213                        Got Me Under Pressure         ZZ Top   1983
# 2214                            Heard It On the X         ZZ Top   1975
# 2215                                  I Thank You         ZZ Top    NaN
# 2216                      I'm Bad, I'm Nationwide         ZZ Top    NaN
# 2217                      Jesus Just Left Chicago         ZZ Top   1973
# 2218                                Just Got Paid         ZZ Top    NaN
# 2219                                    La Grange         ZZ Top   1973
# 2220                                         Legs         ZZ Top   1983
# 2221                     My Head's In Mississippi         ZZ Top    NaN
# 2222                           Party On The Patio         ZZ Top    NaN
# 2223                               Pearl Necklace         ZZ Top   1981
# 2224                            Sharp Dressed Man         ZZ Top   1983
# 2225                      She Loves My Automobile         ZZ Top    NaN
# 2226                            Tube Snake Boogie         ZZ Top   1981
# 2227                                         Tush         ZZ Top   1975
# 2228                                   TV Dinners         ZZ Top   1983
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO         ZZ Top   1973
#
#                                                Song_Art  1st  YR  CountPlay  \
# 0                       Caught Up in You by .38 Special    1   1         82
# 1                           Fantasy Girl by .38 Special    1   0          3
# 2                        Hold On Loosely by .38 Special    1   1         85
# 3                 Rockin' Into the Night by .38 Special    1   1         18
# 4                             Art For Arts Sake by 10cc    1   1          1
# 5                            Kryptonite by 3 Doors Down    1   1         13
# 6                                 Loser by 3 Doors Down    1   1          1
# 7                         When I'm Gone by 3 Doors Down    1   1          6
# 8                           What's Up? by 4 Non Blondes    1   1          3
# 9                                    Take On Me by a-ha    1   1          1
# 10                       Baby, Please Don't Go by AC/DC    1   0          1
# 11                               Back In Black by AC/DC    1   1         97
# 12                                     Big Gun by AC/DC    1   1          6
# 13                      CAN'T STOP ROCK'N'ROLL by AC/DC    1   0          5
# 14                 Dirty Deeds Done Dirt Cheap by AC/DC    1   1         85
# 15                     For Those About To Rock by AC/DC    1   1         46
# 16                            Girls Got Rhythm by AC/DC    1   0         24
# 17                              Hard As A Rock by AC/DC    1   1          1
# 18                          Have a Drink On Me by AC/DC    1   1         39
# 19                                 Hells Bells by AC/DC    1   1         74
# 20                             Highway To Hell by AC/DC    1   1         92
# 21                  It's A Long Way To The Top by AC/DC    1   1         39
# 22                                   Jailbreak by AC/DC    1   1          1
# 23                           Let There Be Rock by AC/DC    1   1          3
# 24                             Let's Get It Up by AC/DC    1   0          4
# 25                                   Live Wire by AC/DC    1   0          2
# 26                                  Moneytalks by AC/DC    1   0         20
# 27                               Night Prowler by AC/DC    1   1          1
# 28         Rock and Roll Ain't Noise Pollution by AC/DC    1   1         21
# 29                             Shoot To Thrill by AC/DC    1   0         45
# ...                                                 ...  ...  ..        ...
# 2200                     Owner of a Lonely Heart by Yes    1   1         81
# 2201                                  Roundabout by Yes    1   1         44
# 2202                            Starship Trooper by Yes    1   1          1
# 2203                           Wonderous Stories by Yes    1   0          5
# 2204                        Yours Is No Disgrace by Yes    1   1          1
# 2205                     Tell Me What You Want by Zebra    1   0          2
# 2206                     Who's Behind The Door by Zebra    1   0          1
# 2207                      Time of the Season by Zombies    1   1         14
# 2208                A Fool for Your Stockings by ZZ Top    1   0          1
# 2209         Arrested For Driving While Blind by ZZ Top    1   1          1
# 2210             Beer Drinkers & Hell Raisers by ZZ Top    1   1          8
# 2211                         Cheap Sunglasses by ZZ Top    1   1         34
# 2212                     Gimme All Your Lovin by ZZ Top    1   1         86
# 2213                    Got Me Under Pressure by ZZ Top    1   1         29
# 2214                        Heard It On the X by ZZ Top    1   1          2
# 2215                              I Thank You by ZZ Top    1   0         16
# 2216                  I'm Bad, I'm Nationwide by ZZ Top    1   0         10
# 2217                  Jesus Just Left Chicago by ZZ Top    1   1          6
# 2218                            Just Got Paid by ZZ Top    1   0          2
# 2219                                La Grange by ZZ Top    1   1        111
# 2220                                     Legs by ZZ Top    1   1        121
# 2221                 My Head's In Mississippi by ZZ Top    1   0          1
# 2222                       Party On The Patio by ZZ Top    1   0         14
# 2223                           Pearl Necklace by ZZ Top    1   1          5
# 2224                        Sharp Dressed Man by ZZ Top    1   1        120
# 2225                  She Loves My Automobile by ZZ Top    1   0          1
# 2226                        Tube Snake Boogie by ZZ Top    1   1         32
# 2227                                     Tush by ZZ Top    1   1        109
# 2228                               TV Dinners by ZZ Top    1   1          1
# 2229  WAITIN' FOR THE BUS/JESUS JUST LEFT CHICAGO by...    1   1          2
#
#       F*G
# 0      82
# 1       0
# 2      85
# 3      18
# 4       1
# 5      13
# 6       1
# 7       6
# 8       3
# 9       1
# 10      0
# 11     97
# 12      6
# 13      0
# 14     85
# 15     46
# 16      0
# 17      1
# 18     39
# 19     74
# 20     92
# 21     39
# 22      1
# 23      3
# 24      0
# 25      0
# 26      0
# 27      1
# 28     21
# 29      0
# ...   ...
# 2200   81
# 2201   44
# 2202    1
# 2203    0
# 2204    1
# 2205    0
# 2206    0
# 2207   14
# 2208    0
# 2209    1
# 2210    8
# 2211   34
# 2212   86
# 2213   29
# 2214    2
# 2215    0
# 2216    0
# 2217    6
# 2218    0
# 2219  111
# 2220  121
# 2221    0
# 2222    0
# 2223    5
# 2224  120
# 2225    0
# 2226   32
# 2227  109
# 2228    1
# 2229    2
#
# [2230 rows x 8 columns]

# %% [markdown]
# ### 3. Subsetting data where null values exist.
#
# We have mixed `str` and `NaN` values in the `release` column. `NaN` stands for "not a number" and is the way `pandas` handles "nulls" or nonexistent data. We can use the `.isnull()` method of a Series to find null values.
#
# Print the header of the data subset to where the `release` column is null values.

# %%
# Show records where df['release'] is null
rf = pd.read_csv(rockfile)
rf.head()
# Out:
#                Song Clean ARTIST CLEAN Release Year  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special          NaN
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                 COMBINED  First?  Year?  PlayCount  F*G
# 0        Caught Up in You by .38 Special       1      1         82   82
# 1            Fantasy Girl by .38 Special       1      0          3    0
# 2         Hold On Loosely by .38 Special       1      1         85   85
# 3  Rockin' Into the Night by .38 Special       1      1         18   18
# 4              Art For Arts Sake by 10cc       1      1          1    1

# %%
rf[rf['Release Year'].isnull()]
# Out:
#                               Song Clean              ARTIST CLEAN  \
# 1                           Fantasy Girl               .38 Special
# 10                 Baby, Please Don't Go                     AC/DC
# 13                CAN'T STOP ROCK'N'ROLL                     AC/DC
# 16                      Girls Got Rhythm                     AC/DC
# 24                       Let's Get It Up                     AC/DC
# 25                             Live Wire                     AC/DC
# 26                            Moneytalks                     AC/DC
# 29                       Shoot To Thrill                     AC/DC
# 31                              Sin City                     AC/DC
# 35        What Do You Do For Money Honey                     AC/DC
# 42                 Baby, Please Don't Go                 Aerosmith
# 45                         Come Together                 Aerosmith
# 53                      Kings and Queens                 Aerosmith
# 60                        One Way Street                 Aerosmith
# 66                        The Other Side                 Aerosmith
# 71                     You See Me Crying                 Aerosmith
# 75                               Fantasy                 Aldo Nova
# 76                           BE MY LOVER              Alice Cooper
# 80                         House Of Fire              Alice Cooper
# 100                          One Way Out      Allman Brothers Band
# 102                           Southbound      Allman Brothers Band
# 104                        Whippin' Post      Allman Brothers Band
# 110                       Immigrant Song                Ann Wilson
# 111                               Roller                April Wine
# 113              Coming into Los Angeles              Arlo Guthrie
# 114                              Wayside             Artful Dodger
# 118                               Spooky    Atlanta Rhythm Section
# 120                Blondes In Black Cars                 Autograph
# 122   Rock And Roll Party In The Streets                       Axe
# 124             Roll On Down The Highway  Bachman-Turner Overdrive
# ...                                  ...                       ...
# 2149              Take Your Whiskey Home                 Van Halen
# 2150                           Top Jimmy                 Van Halen
# 2151                    Top of the World                 Van Halen
# 2157                    And It Stoned Me              Van Morrison
# 2158                          BLUE MONEY              Van Morrison
# 2162                              Gloria              Van Morrison
# 2164                  Jackie Wilson Said              Van Morrison
# 2168              Edge of a Broken Heart                     Vixen
# 2174                   Uncle Tom's Cabin                   Warrant
# 2178              Street Corner Serenade                Wet Willie
# 2179                                Wait                White Lion
# 2184                       Slow An' Easy                Whitesnake
# 2185                  Still of the Night                Whitesnake
# 2186                        Who Are You?                   Why Not
# 2188                         Night Moves                  Wildlife
# 2189                   We've Got Tonight                  Wildlife
# 2190                    Can't Get Enough                    Winger
# 2191             Headed For A Heartbreak                    Winger
# 2192                           Seventeen                    Winger
# 2194                    Summertime Girls                       Y&T
# 2203                   Wonderous Stories                       Yes
# 2205               Tell Me What You Want                     Zebra
# 2206               Who's Behind The Door                     Zebra
# 2208           A Fool for Your Stockings                    ZZ Top
# 2215                         I Thank You                    ZZ Top
# 2216             I'm Bad, I'm Nationwide                    ZZ Top
# 2218                       Just Got Paid                    ZZ Top
# 2221            My Head's In Mississippi                    ZZ Top
# 2222                  Party On The Patio                    ZZ Top
# 2225             She Loves My Automobile                    ZZ Top
#
#      Release Year                                           COMBINED  First?  \
# 1             NaN                        Fantasy Girl by .38 Special       1
# 10            NaN                     Baby, Please Don't Go by AC/DC       1
# 13            NaN                    CAN'T STOP ROCK'N'ROLL by AC/DC       1
# 16            NaN                          Girls Got Rhythm by AC/DC       1
# 24            NaN                           Let's Get It Up by AC/DC       1
# 25            NaN                                 Live Wire by AC/DC       1
# 26            NaN                                Moneytalks by AC/DC       1
# 29            NaN                           Shoot To Thrill by AC/DC       1
# 31            NaN                                  Sin City by AC/DC       1
# 35            NaN            What Do You Do For Money Honey by AC/DC       1
# 42            NaN                 Baby, Please Don't Go by Aerosmith       1
# 45            NaN                         Come Together by Aerosmith       1
# 53            NaN                      Kings and Queens by Aerosmith       1
# 60            NaN                        One Way Street by Aerosmith       1
# 66            NaN                        The Other Side by Aerosmith       1
# 71            NaN                     You See Me Crying by Aerosmith       1
# 75            NaN                               Fantasy by Aldo Nova       1
# 76            NaN                        BE MY LOVER by Alice Cooper       1
# 80            NaN                      House Of Fire by Alice Cooper       1
# 100           NaN                One Way Out by Allman Brothers Band       1
# 102           NaN                 Southbound by Allman Brothers Band       1
# 104           NaN              Whippin' Post by Allman Brothers Band       1
# 110           NaN                       Immigrant Song by Ann Wilson       1
# 111           NaN                               Roller by April Wine       1
# 113           NaN            Coming into Los Angeles by Arlo Guthrie       1
# 114           NaN                           Wayside by Artful Dodger       1
# 118           NaN                   Spooky by Atlanta Rhythm Section       1
# 120           NaN                 Blondes In Black Cars by Autograph       1
# 122           NaN          Rock And Roll Party In The Streets by Axe       1
# 124           NaN  Roll On Down The Highway by Bachman-Turner Ove...       1
# ...           ...                                                ...     ...
# 2149          NaN                Take Your Whiskey Home by Van Halen       1
# 2150          NaN                             Top Jimmy by Van Halen       1
# 2151          NaN                      Top of the World by Van Halen       1
# 2157          NaN                   And It Stoned Me by Van Morrison       1
# 2158          NaN                         BLUE MONEY by Van Morrison       1
# 2162          NaN                             Gloria by Van Morrison       1
# 2164          NaN                 Jackie Wilson Said by Van Morrison       1
# 2168          NaN                    Edge of a Broken Heart by Vixen       1
# 2174          NaN                       Uncle Tom's Cabin by Warrant       1
# 2178          NaN               Street Corner Serenade by Wet Willie       1
# 2179          NaN                                 Wait by White Lion       1
# 2184          NaN                        Slow An' Easy by Whitesnake       1
# 2185          NaN                   Still of the Night by Whitesnake       1
# 2186          NaN                            Who Are You? by Why Not       1
# 2188          NaN                            Night Moves by Wildlife       1
# 2189          NaN                      We've Got Tonight by Wildlife       1
# 2190          NaN                         Can't Get Enough by Winger       1
# 2191          NaN                  Headed For A Heartbreak by Winger       1
# 2192          NaN                                Seventeen by Winger       1
# 2194          NaN                            Summertime Girls by Y&T       1
# 2203          NaN                           Wonderous Stories by Yes       1
# 2205          NaN                     Tell Me What You Want by Zebra       1
# 2206          NaN                     Who's Behind The Door by Zebra       1
# 2208          NaN                A Fool for Your Stockings by ZZ Top       1
# 2215          NaN                              I Thank You by ZZ Top       1
# 2216          NaN                  I'm Bad, I'm Nationwide by ZZ Top       1
# 2218          NaN                            Just Got Paid by ZZ Top       1
# 2221          NaN                 My Head's In Mississippi by ZZ Top       1
# 2222          NaN                       Party On The Patio by ZZ Top       1
# 2225          NaN                  She Loves My Automobile by ZZ Top       1
#
#       Year?  PlayCount  F*G
# 1         0          3    0
# 10        0          1    0
# 13        0          5    0
# 16        0         24    0
# 24        0          4    0
# 25        0          2    0
# 26        0         20    0
# 29        0         45    0
# 31        0          1    0
# 35        0          2    0
# 42        0          1    0
# 45        0         65    0
# 53        0          1    0
# 60        0          1    0
# 66        0         11    0
# 71        0          1    0
# 75        0          4    0
# 76        0          1    0
# 80        0          1    0
# 100       0          3    0
# 102       0          2    0
# 104       0          6    0
# 110       0          2    0
# 111       0          1    0
# 113       0          1    0
# 114       0          1    0
# 118       0          1    0
# 120       0          1    0
# 122       0          1    0
# 124       0          5    0
# ...     ...        ...  ...
# 2149      0          8    0
# 2150      0         23    0
# 2151      0          5    0
# 2157      0          1    0
# 2158      0          1    0
# 2162      0          1    0
# 2164      0          1    0
# 2168      0          2    0
# 2174      0          1    0
# 2178      0          2    0
# 2179      0          1    0
# 2184      0          6    0
# 2185      0         14    0
# 2186      0          5    0
# 2188      0         23    0
# 2189      0          4    0
# 2190      0          1    0
# 2191      0          1    0
# 2192      0          2    0
# 2194      0          4    0
# 2203      0          5    0
# 2205      0          2    0
# 2206      0          1    0
# 2208      0          1    0
# 2215      0         16    0
# 2216      0         10    0
# 2218      0          2    0
# 2221      0          1    0
# 2222      0         14    0
# 2225      0          1    0
#
# [577 rows x 8 columns]

# %% [markdown]
# ### 4. Update slices of your DataFrame based on mask selection/slices.
#
# In many scenarios, we want to upate values in our DataFrame according to criteria. Let's say we wanted to set all of the null values in `release` to 0.
#
# With newer versions of `pandas`, in order to manipulate data in the original DataFrame, we have to use `.loc` while performing reassignment using a mask and an index.
#
# For example, the following won't always work:
# ```python
# df[row_mask]['column_name'] = new_value
# ```
#
# The best way to accomplish the same task is:
# ```python
# df.loc[row_mask, 'column_name'] = new_value
# ```
#
# For multiple column assignment, you would use:
# ```python
# df.loc[row_mask, ['col_1', 'col_2', 'col_3']] = new_value
# ```
#
# #### 4.A Let's try it out. Make all of the null values in `release` 0.

# %%
# Replace release nulls with 0
###rf.loc[:, rf.isnull().sum() > 0 ]This shows all the Null Values

rel_null_val = rf['Release Year'].isnull()
rf.loc[rel_null_val, 'Release Year'] = 0

rf.head()
# Out:
#                Song Clean ARTIST CLEAN Release Year  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special            0
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                 COMBINED  First?  Year?  PlayCount  F*G
# 0        Caught Up in You by .38 Special       1      1         82   82
# 1            Fantasy Girl by .38 Special       1      0          3    0
# 2         Hold On Loosely by .38 Special       1      1         85   85
# 3  Rockin' Into the Night by .38 Special       1      1         18   18
# 4              Art For Arts Sake by 10cc       1      1          1    1

# %% [markdown]
# #### 4.B Verify that `release` contains no null values.

# %%
# A:
rf.isnull()
# Out:
#       Song Clean  ARTIST CLEAN  Release Year  COMBINED  First?  Year?  \
# 0          False         False         False     False   False  False
# 1          False         False         False     False   False  False
# 2          False         False         False     False   False  False
# 3          False         False         False     False   False  False
# 4          False         False         False     False   False  False
# 5          False         False         False     False   False  False
# 6          False         False         False     False   False  False
# 7          False         False         False     False   False  False
# 8          False         False         False     False   False  False
# 9          False         False         False     False   False  False
# 10         False         False         False     False   False  False
# 11         False         False         False     False   False  False
# 12         False         False         False     False   False  False
# 13         False         False         False     False   False  False
# 14         False         False         False     False   False  False
# 15         False         False         False     False   False  False
# 16         False         False         False     False   False  False
# 17         False         False         False     False   False  False
# 18         False         False         False     False   False  False
# 19         False         False         False     False   False  False
# 20         False         False         False     False   False  False
# 21         False         False         False     False   False  False
# 22         False         False         False     False   False  False
# 23         False         False         False     False   False  False
# 24         False         False         False     False   False  False
# 25         False         False         False     False   False  False
# 26         False         False         False     False   False  False
# 27         False         False         False     False   False  False
# 28         False         False         False     False   False  False
# 29         False         False         False     False   False  False
# ...          ...           ...           ...       ...     ...    ...
# 2200       False         False         False     False   False  False
# 2201       False         False         False     False   False  False
# 2202       False         False         False     False   False  False
# 2203       False         False         False     False   False  False
# 2204       False         False         False     False   False  False
# 2205       False         False         False     False   False  False
# 2206       False         False         False     False   False  False
# 2207       False         False         False     False   False  False
# 2208       False         False         False     False   False  False
# 2209       False         False         False     False   False  False
# 2210       False         False         False     False   False  False
# 2211       False         False         False     False   False  False
# 2212       False         False         False     False   False  False
# 2213       False         False         False     False   False  False
# 2214       False         False         False     False   False  False
# 2215       False         False         False     False   False  False
# 2216       False         False         False     False   False  False
# 2217       False         False         False     False   False  False
# 2218       False         False         False     False   False  False
# 2219       False         False         False     False   False  False
# 2220       False         False         False     False   False  False
# 2221       False         False         False     False   False  False
# 2222       False         False         False     False   False  False
# 2223       False         False         False     False   False  False
# 2224       False         False         False     False   False  False
# 2225       False         False         False     False   False  False
# 2226       False         False         False     False   False  False
# 2227       False         False         False     False   False  False
# 2228       False         False         False     False   False  False
# 2229       False         False         False     False   False  False
#
#       PlayCount    F*G
# 0         False  False
# 1         False  False
# 2         False  False
# 3         False  False
# 4         False  False
# 5         False  False
# 6         False  False
# 7         False  False
# 8         False  False
# 9         False  False
# 10        False  False
# 11        False  False
# 12        False  False
# 13        False  False
# 14        False  False
# 15        False  False
# 16        False  False
# 17        False  False
# 18        False  False
# 19        False  False
# 20        False  False
# 21        False  False
# 22        False  False
# 23        False  False
# 24        False  False
# 25        False  False
# 26        False  False
# 27        False  False
# 28        False  False
# 29        False  False
# ...         ...    ...
# 2200      False  False
# 2201      False  False
# 2202      False  False
# 2203      False  False
# 2204      False  False
# 2205      False  False
# 2206      False  False
# 2207      False  False
# 2208      False  False
# 2209      False  False
# 2210      False  False
# 2211      False  False
# 2212      False  False
# 2213      False  False
# 2214      False  False
# 2215      False  False
# 2216      False  False
# 2217      False  False
# 2218      False  False
# 2219      False  False
# 2220      False  False
# 2221      False  False
# 2222      False  False
# 2223      False  False
# 2224      False  False
# 2225      False  False
# 2226      False  False
# 2227      False  False
# 2228      False  False
# 2229      False  False
#
# [2230 rows x 8 columns]

# %%
rf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 8 columns):
# Song Clean      2230 non-null object
# ARTIST CLEAN    2230 non-null object
# Release Year    2230 non-null object
# COMBINED        2230 non-null object
# First?          2230 non-null int64
# Year?           2230 non-null int64
# PlayCount       2230 non-null int64
# F*G             2230 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 139.5+ KB

# %% [markdown]
# ### 5. Ensure that the data types of the columns make sense.
#
# Verifying column data types is a critical part of data munging. If columns have the wrong data type, then there is usually corrupted or incorrect data in some of the observations.
#
# #### 5.A Look at the data types for the columns. Are any incorrect given what the data represents?

# %%
# A:
rf.dtypes ###Object are genric, sim to a python string, example it could be a list.
# Out:
# Song Clean      object
# ARTIST CLEAN    object
# Release Year    object
# COMBINED        object
# First?           int64
# Year?            int64
# PlayCount        int64
# F*G              int64
# dtype: object

# %% [markdown]
# ### 6. Investigate and clean up the `release` column.
#
# The `release` column is a string data type when it should be an integer.
#
# #### 6.A Figure out what value(s) are causing the `release` column to be encoded as a string instead of an integer.

# %%
# A:
rf['Release Year'].unique()
# Out:
# array(['1982', 0, '1981', '1980', '1975', '2000', '2002', '1992', '1985',
#        '1993', '1976', '1995', '1979', '1984', '1977', '1990', '1986',
#        '1974', '2014', '1987', '1973', '2001', '1989', '1997', '1971',
#        '1972', '1994', '1970', '1966', '1965', '1983', '1955', '1978',
#        '1969', '1999', '1968', '1988', '1962', '2007', '1967', '1958',
#        '1071', '1996', '1991', '2005', '2011', '2004', '2012', '2003',
#        '1998', '2008', '1964', '2013', '2006', 'SONGFACTS.COM', '1963',
#        '1961'], dtype=object)

# %%
rf['Release Year'] = rf['Release Year'].astype(str) ###Another way to look up is:

# %%
rf[~rf['Release Year'].str.isdigit()] ###~ means not true
# Out:
# Empty DataFrame
# Columns: [Song Clean, ARTIST CLEAN, Release Year, COMBINED, First?, Year?, PlayCount, F*G]
# Index: []

# %% [markdown]
# #### 6.B Look at the rows in which there is incorrect data in the `release` column.

# %%
# A:
obj_rel = rf['Release Year'] == 'SONGFACTS.COM'
rf[obj_rel]
# Out:
#           Song Clean    ARTIST CLEAN   Release Year  \
# 1504  Bullfrog Blues  Rory Gallagher  SONGFACTS.COM
#
#                               COMBINED  First?  Year?  PlayCount  F*G
# 1504  Bullfrog Blues by Rory Gallagher       1      1          1    1

# %% [markdown]
# #### 6.C. Clean up the data. Normally we may replace the offending data with null np.nan values, however we previously converted all of the nan values in the release column to zeros so we might as well continue with the same practice. Replacing with 0 (or nan) will allow us to convert the column to numeric.

# %%
rf.loc[obj_rel, 'Release Year'] = np.nan ###np.nan is what? 
rf['Release Year'] = rf['Release Year'].map(lambda x: float(x))

rf.dtypes ###NOT sure how this happened.
# Out:
# Song Clean       object
# ARTIST CLEAN     object
# Release Year    float64
# COMBINED         object
# First?            int64
# Year?             int64
# PlayCount         int64
# F*G               int64
# dtype: object

# %% [markdown]
# ### 7. Get summary statistics for the `release` column using the `.describe()` function.
#
# Now that the `release` column is finally a numeric data type, we can apply the `.describe()` function.
#
# #### 7.A Print out the summary stats for the `release` column. What is the earliest and latest release date?

# %%
# A:
rf['Release Year'].describe()
# Out:
# count    2230.000000
# mean     1465.331390
# std       867.196161
# min         0.000000
# 25%         0.000000
# 50%      1973.000000
# 75%      1981.000000
# max      2014.000000
# Name: Release Year, dtype: float64

# %% [markdown]
# #### 7.B Based on the summary statistics, is there anything else wrong with the `release` column?

# %%
# A:

# %% [markdown]
# _Looking at the DataFrame that contains the year 1071, we can see that the year was probably corrupted and should be replaced with something else if possible._

# %% [markdown]
# ### 8. Make changes and investigate using custom functions with `.apply()`.
#
# Let's say we want to traverse every single row in our data set and apply a function to that row.
#
# #### 8.A Write a function that will take a row of a DataFrame and print out the song, artist, and whether or not the release date is < 1970.

# %%
# A:
def release_inspector(row)

# %% [markdown]
# #### 8.B Using the `.apply()` function, apply the function you wrote to the first four rows of the DataFrame.
#
# You will need to tell the `apply` function to operate row by row. Setting the keyword argument as `axis=1` indicates that the function should be applied to each row individually.

# %%
# A:
