# %%
import pandas as pd
import numpy as np

# %%
df1 =pd.read_excel('/Users/swllms/DAT-10-14-SW/class material/Unit2/data/merge1.xlsx')
df2 =pd.read_excel('/Users/swllms/DAT-10-14-SW/class material/Unit2/data/merge2.xlsx')

# %%
df2.head()
# Out:
#    ID   Name  Gender
# 0   1   Jill  Female
# 1   2   Jack    Male
# 2   3    Jim    Male
# 3   4  Janet  Female
# 4   6   Jane  Female

# %%
df1.head()
# Out:
#    ID   Name  Age
# 0   1   Jill   23
# 1   2   Jack   45
# 2   3    Jim   21
# 3   4  Janet   47
# 4   5    Joe   87

# %%
pd.merge(df1, df2, on='ID', how='inner')
# Out:
#    ID Name_x  Age Name_y  Gender
# 0   1   Jill   23   Jill  Female
# 1   2   Jack   45   Jack    Male
# 2   3    Jim   21    Jim    Male
# 3   4  Janet   47  Janet  Female
# 4   6   Jane   21   Jane  Female
# 5   7   Jobe   46   Jobe    Male
# 6   8  Josie   43  Josie  Female
# 7   9   Jean   54   Jean    Male

# %%
pd.merge(df1, df2, on='ID', how='left')
# Out:
#    ID Name_x  Age Name_y  Gender
# 0   1   Jill   23   Jill  Female
# 1   2   Jack   45   Jack    Male
# 2   3    Jim   21    Jim    Male
# 3   4  Janet   47  Janet  Female
# 4   5    Joe   87    NaN     NaN
# 5   6   Jane   21   Jane  Female
# 6   7   Jobe   46   Jobe    Male
# 7   8  Josie   43  Josie  Female
# 8   9   Jean   54   Jean    Male
# 9  10   Jess   34    NaN     NaN

# %%
pd.merge(df1, df2, on='ID', how='right')
# Out:
#    ID Name_x   Age   Name_y  Gender
# 0   1   Jill  23.0     Jill  Female
# 1   2   Jack  45.0     Jack    Male
# 2   3    Jim  21.0      Jim    Male
# 3   4  Janet  47.0    Janet  Female
# 4   6   Jane  21.0     Jane  Female
# 5   7   Jobe  46.0     Jobe    Male
# 6   8  Josie  43.0    Josie  Female
# 7   9   Jean  54.0     Jean    Male
# 8  11    NaN   NaN    Jacob    Male
# 9  12    NaN   NaN  Jasmine  Female

# %%
df = pd.read_csv('/Users/swllms/DAT-10-14-SW/class material/Unit1/data/titanic.csv')

# %%
df[df.Sex == 'female']['Survived'] = 12 ###SettingWithCopyWarning is
# Out:
# /Users/swllms/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df.isnull() ### shows you missing values in database .notnull will show you all fields that have a value
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.notnull().sum()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df.isnull().sum() > 0 ###Does colms have null data contained
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
###loc is label based location
df.loc[:, df.isnull().sum() > 0 ] ###Can select colms that meet certain conditions.
# Out:
#       Age        Cabin Embarked
# 0    22.0          NaN        S
# 1    38.0          C85        C
# 2    26.0          NaN        S
# 3    35.0         C123        S
# 4    35.0          NaN        S
# 5     NaN          NaN        Q
# 6    54.0          E46        S
# 7     2.0          NaN        S
# 8    27.0          NaN        S
# 9    14.0          NaN        C
# 10    4.0           G6        S
# 11   58.0         C103        S
# 12   20.0          NaN        S
# 13   39.0          NaN        S
# 14   14.0          NaN        S
# 15   55.0          NaN        S
# 16    2.0          NaN        Q
# 17    NaN          NaN        S
# 18   31.0          NaN        S
# 19    NaN          NaN        C
# 20   35.0          NaN        S
# 21   34.0          D56        S
# 22   15.0          NaN        Q
# 23   28.0           A6        S
# 24    8.0          NaN        S
# 25   38.0          NaN        S
# 26    NaN          NaN        C
# 27   19.0  C23 C25 C27        S
# ...

# %%
df.select_dtypes(include=np.number)
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare
# 0              1         0       3  22.0      1      0    7.2500
# 1              2         1       1  38.0      1      0   71.2833
# 2              3         1       3  26.0      0      0    7.9250
# 3              4         1       1  35.0      1      0   53.1000
# 4              5         0       3  35.0      0      0    8.0500
# 5              6         0       3   NaN      0      0    8.4583
# 6              7         0       1  54.0      0      0   51.8625
# 7              8         0       3   2.0      3      1   21.0750
# 8              9         1       3  27.0      0      2   11.1333
# 9             10         1       2  14.0      1      0   30.0708
# 10            11         1       3   4.0      1      1   16.7000
# 11            12         1       1  58.0      0      0   26.5500
# 12            13         0       3  20.0      0      0    8.0500
# ...

# %%
num_cols = df.select_dtypes(include=np.number).columns.tolist()

# %%
df[num_cols].isnull().sum() >0 ###For all num colms what has no value
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Age             True
# SibSp          False
# Parch          False
# Fare           False
# dtype: bool

# %%
df[num_cols].mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
df[num_cols] = df[num_cols].fillna(df[num_cols].mean())

# %%
df[num_cols]
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0              1         0       3  22.000000      1      0    7.2500
# 1              2         1       1  38.000000      1      0   71.2833
# 2              3         1       3  26.000000      0      0    7.9250
# 3              4         1       1  35.000000      1      0   53.1000
# 4              5         0       3  35.000000      0      0    8.0500
# 5              6         0       3  29.699118      0      0    8.4583
# 6              7         0       1  54.000000      0      0   51.8625
# 7              8         0       3   2.000000      3      1   21.0750
# 8              9         1       3  27.000000      0      2   11.1333
# 9             10         1       2  14.000000      1      0   30.0708
# 10            11         1       3   4.000000      1      1   16.7000
# 11            12         1       1  58.000000      0      0   26.5500
# ...

# %%
df[df['Age'].duplicated()] ###duplicate(subset = None, keep=first)
# Out:
#      PassengerId  Survived  Pclass  \
# 4              5         0       3
# 14            15         0       3
# 16            17         0       3
# 17            18         1       2
# 19            20         1       3
# 20            21         0       2
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 34            35         0       1
# 36            37         1       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 42            43         0       3
# 44            45         1       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 49            50         0       3
# 51            52         0       3
# ...

# %%
#### Group by functions works sim to a pivot table

df.groupby('Pclass').sum()
# Out:
#         PassengerId  Survived           Age  SibSp  Parch        Fare
# Pclass
# 1             99705       136   8002.393529     90     77  18177.4125
# 2             82056        87   5495.520294     74     70   3801.8417
# 3            215625       119  12964.000000    302    193   6714.6951

# %%
df.groupby(['Sex', 'Pclass']).mean() ## Group by multi colms pass into the groupby()
# Out:
#                PassengerId  Survived        Age     SibSp     Parch  \
# Sex    Pclass
# female 1        469.212766  0.968085  34.141405  0.553191  0.457447
#        2        443.105263  0.921053  28.748661  0.486842  0.605263
#        3        399.729167  0.500000  24.068493  0.895833  0.798611
# male   1        455.729508  0.368852  39.287717  0.311475  0.278689
#        2        447.962963  0.157407  30.653908  0.342593  0.222222
#        3        455.515850  0.135447  27.372153  0.498559  0.224784
#
#                      Fare
# Sex    Pclass
# female 1       106.125798
#        2        21.970121
#        3        16.118810
# male   1        67.226127
#        2        19.741782
#        3        12.661633

# %%
df.groupby(['Sex', 'Pclass'])['Survived', 'Age'].mean() 
### select a series 
### Series is one colm, DataFrame is multi colms
# Out:
#                Survived        Age
# Sex    Pclass
# female 1       0.968085  34.141405
#        2       0.921053  28.748661
#        3       0.500000  24.068493
# male   1       0.368852  39.287717
#        2       0.157407  30.653908
#        3       0.135447  27.372153

# %%
df.groupby(['Sex', 'Pclass'])['Age'].describe()
# Out:
#                count       mean        std   min        25%        50%  \
# Sex    Pclass
# female 1        94.0  34.141405  13.018018  2.00  24.000000  32.500000
#        2        76.0  28.748661  12.700880  2.00  22.750000  28.500000
#        3       144.0  24.068493  11.296112  0.75  18.000000  28.000000
# male   1       122.0  39.287717  14.446502  0.92  29.699118  36.000000
#        2       108.0  30.653908  14.161010  0.67  23.000000  29.699118
#        3       347.0  27.372153  10.473922  0.42  21.000000  29.699118
#
#                      75%   max
# Sex    Pclass
# female 1       42.750000  63.0
#        2       36.000000  57.0
#        3       29.699118  63.0
# male   1       49.000000  80.0
#        2       36.000000  70.0
#        3       30.000000  74.0

# %%
df.groupby(['Sex', 'Pclass'])['Age'].agg(['mean', 'sum']) 

#### allows multi functions to happen
# Out:
#                     mean          sum
# Sex    Pclass
# female 1       34.141405  3209.292059
#        2       28.748661  2184.898235
#        3       24.068493  3465.862941
# male   1       39.287717  4793.101471
#        2       30.653908  3310.622059
#        3       27.372153  9498.137059

# %%
df[df['Embarked'] == 'Q'].groupby(['Sex', 'Pclass'])['Age'].agg(['mean', 'sum']) 

### Selector, groupby colms, agg
# Out:
#                     mean          sum
# Sex    Pclass
# female 1       33.000000    33.000000
#        2       29.849559    59.699118
#        3       27.623627   911.579706
# male   1       44.000000    44.000000
#        2       57.000000    57.000000
#        3       29.140460  1136.477941

# %%
sales = pd.read_excel('/Users/swllms/DAT-10-14/class material/Unit2/data/superstore.xls')

# %%
sales.head()

# %%
sales = sales.set_index('Order Date')

# %%
sales.head()

# %%
sales.resample('M')['Sales'].sum()

# %%
sales.resample('15min')['Sales'].sum()

# %%
sales.resample('M')['Sales'].sum()
