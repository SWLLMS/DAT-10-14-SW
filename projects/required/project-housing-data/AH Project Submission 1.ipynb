# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('/Users/swllms/DAT-10-14-SW/class material/Unit3/Data/iowa_housing/train.csv', usecols=[1, 17, 18, 19, 43, 44, 46, 49, 50, 70, 77, 80])
test  = pd.read_csv('/Users/swllms/DAT-10-14-SW/class material/Unit3/Data/iowa_housing/test.csv', usecols=[1, 17, 18, 19, 43, 44, 46, 49, 50, 70, 77])

# %%
train.head() #has the sale price
# Out:
#    MSSubClass  OverallQual  OverallCond  YearBuilt  1stFlrSF  2ndFlrSF  \
# 0          60            7            5       2003       856       854
# 1          20            6            8       1976      1262         0
# 2          60            7            5       2001       920       866
# 3          70            7            5       1915       961       756
# 4          60            8            5       2000      1145      1053
#
#    GrLivArea  FullBath  HalfBath  ScreenPorch  YrSold  SalePrice
# 0       1710         2         1            0    2008     208500
# 1       1262         2         0            0    2007     181500
# 2       1786         2         1            0    2008     223500
# 3       1717         1         0            0    2006     140000
# 4       2198         2         1            0    2008     250000

# %%
test.head() #does not have a the target colm (sale price)
# Out:
#    MSSubClass  OverallQual  OverallCond  YearBuilt  1stFlrSF  2ndFlrSF  \
# 0          20            5            6       1961       896         0
# 1          20            6            6       1958      1329         0
# 2          60            5            5       1997       928       701
# 3          60            6            6       1998       926       678
# 4         120            8            5       1992      1280         0
#
#    GrLivArea  FullBath  HalfBath  ScreenPorch  YrSold
# 0        896         1         0          120    2010
# 1       1329         1         1            0    2010
# 2       1629         2         1            0    2010
# 3       1604         2         1            0    2010
# 4       1280         2         0          144    2010

# %%
X_train, y_train = train.loc[:, train.columns != 'SalePrice'], np.log(train['SalePrice'])

# %% [markdown]
# root mean log square error is used for homework 3.

# %%
def rmse(estimator, X, y):
    preds  = estimator.predict(X)
    error = np.sqrt(np.mean((preds - y)**2))
    return error

# %%
#test the number of samples per leaf
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

rf = RandomForestRegressor()

samples_per_leaf = [1, 5, 10, 15, 25, 50]
rf_scores = []


for num_samples in samples_per_leaf:
    rf.set_params(min_samples_leaf=num_samples)
    scores = cross_val_score(estimator=rf, X=X_train, y=y_train, scoring=rmse, cv=10)
    rf_scores.append((np.mean(scores), num_samples))
# Out:
# /Users/swllms/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/swllms/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/swllms/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/swllms/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
rf_scores
# Out:
# [(0.1641459857513868, 1),
#  (0.1642276944607489, 5),
#  (0.16806325819178486, 10),
#  (0.17173431254878696, 15),
#  (0.17858249851292635, 25),
#  (0.1964225095341527, 50)]

# %%
rf.fit(X_train, y_train)
# Out:
# /Users/swllms/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=50, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
test['Prediction'] = rf.predict(test)

# %%
This should be the submission file

# %%
np.exp(test.Prediction)
# Out:
# 0       120722.306728
# 1       147509.048061
# 2       139536.181761
# 3       173343.702700
# 4       244173.995420
# 5       175125.078541
# 6       156552.390675
# 7       168832.476855
# 8       198112.732064
# 9       108330.287316
# 10      198112.732064
# 11      115720.060471
# 12      114926.886523
# 13      166568.105030
# 14      173944.962670
# 15      310747.071072
# 16      253152.440572
# 17      277947.254665
# 18      308567.412675
# 19      336707.782013
# 20      310747.071072
# 21      246948.996367
# 22      159618.552649
# 23      175921.821161
# 24      175921.821161
# 25      191552.773020
# 26      310747.071072
# 27      253152.440572
# 28      175921.821161
# 29      168832.476855
#             ...
# 1429     93891.067748
# 1430    164675.496553
# 1431     93891.067748
# 1432    140300.229431
# 1433     93891.067748
# 1434    277947.254665
# 1435    253152.440572
# 1436    173343.702700
# 1437    172776.310691
# 1438    253152.440572
# ...

# %%
output = pd.DataFrame({
    'Id'       : np.arange(1461, 2920),
    'SalePrice': np.exp(test.Prediction)
})

# %%
output.head()
# Out:
#      Id      SalePrice
# 0  1461  120722.306728
# 1  1462  147509.048061
# 2  1463  139536.181761
# 3  1464  173343.702700
# 4  1465  244173.995420

# %%
output.to_csv('/Users/swllms/DAT-10-14-SW/class material/Unit3/Data/iowa_housing/sample_predictions-sw.csv', index=False)
